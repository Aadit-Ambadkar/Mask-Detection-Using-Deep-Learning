# %%
from fastai.vision import *

# %%
path = Path('/content/drive/My Drive/Masks'); path
# Out:
# PosixPath('/content/drive/My Drive/Masks')

# %%
classes = ['Mask_Improper', 'Mask_Proper', 'No_Mask']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# Mask_Improper
# Mask_Proper
# No_Mask

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Mask_Improper', 'Mask_Proper', 'No_Mask'], 3, 368, 91)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
lr = (1e-02)/2; lr
# Out:
# 0.005

# %%
learn.fit_one_cycle(7, max_lr=slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.537171</td>
#       <td>1.761226</td>
#       <td>0.626374</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.978280</td>
#       <td>0.699986</td>
#       <td>0.208791</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.739114</td>
#       <td>0.183857</td>
#       <td>0.076923</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.566927</td>
#       <td>0.151307</td>
#       <td>0.065934</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.478256</td>
#       <td>0.159148</td>
#       <td>0.054945</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [12/20 01:54<01:16]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.090680</td>
#       <td>0.196339</td>
#       <td>0.087912</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.093662</td>
#       <td>0.201151</td>
#       <td>0.087912</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.078611</td>
#       <td>0.288181</td>
#       <td>0.087912</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.062814</td>
#       <td>0.228291</td>
#       <td>0.076923</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.055139</td>
#       <td>0.197626</td>
#       <td>0.076923</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.freeze()

# %%
learn.save(path/'save1')

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [12/20 01:50<01:13]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
import random
import time
import matplotlib.image as mpimg

# %%
lst = random.sample(range(0, len(data.valid_ds)-1), 6)

# %%
fig = plt.figure(figsize=(16,8))
for i in range(6) :
    k = lst[i]
    pred = learn.predict(data.valid_ds[k][0])
    img = mpimg.imread(data.valid_ds.x.items[k])
    fig.add_subplot(2,3,i+1)
    plt.imshow(img)
    plt.title("Pred: " + pred[0].obj + " / Actual: " + data.valid_ds[k][1].obj)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
preds, y = learn.get_preds(ds_type=DatasetType.Valid)
acc = accuracy(preds, y)
acc
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...
